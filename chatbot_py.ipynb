# %% [markdown]
# <a href="https://colab.research.google.com/github/mandarisumanth86-star/Calculator1/blob/main/chatbot_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CodeAlpha Task 4 - Basic Chatbot

def chatbot():
    print("=" * 40)
    print("      CODEALPHA BASIC CHATBOT")
    print("=" * 40)
    print("Type 'bye' to exit.\n")

    while True:
        user = input("You: ").lower().strip()

        if user == "hello":
            print("Bot: Hi! Nice to meet you.")

        elif user == "hi":
            print("Bot: Hello! How can I help you?")

        elif user == "how are you":
            print("Bot: I'm fine, thanks for asking!")

        elif user == "what is your name":
            print("Bot: I'm the CodeAlpha Chatbot.")

        elif user == "who created you":
            print("Bot: I was created using Python.")

        elif user == "thank you":
            print("Bot: You're welcome!")

        elif user == "bye":
            print("Bot: Goodbye! Have a great day.")
            break

        else:
            print("Bot: Sorry, I don't understand that.")

chatbot()
# Out:
# ...
#       CODEALPHA BASIC CHATBOT
# ...
# Type 'bye' to exit.
#
# You: hi
# Bot: Hello! How can I help you?
# You: how are you?
# Bot: Sorry, I don't understand that.
# You: how are you
# Bot: I'm fine, thanks for asking!
